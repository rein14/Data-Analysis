# %%
# %pip install pandas-profiling

# %load_ext autoreload
# %autoreload 2
# Out:
# ...
#   Using cached pandas_profiling-3.4.0-py2.py3-none-any.whl (315 kB)
# ...
#   Using cached multimethod-1.9-py3-none-any.whl (10 kB)
# ...
#   Using cached missingno-0.5.1-py3-none-any.whl (8.7 kB)
# ...
#   Using cached visions-0.7.5-py3-none-any.whl (102 kB)
# ...
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
# ...
#   Using cached tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# ...
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27096 sha256=1fac9d086654b31fc75b9e17d2186c56203502a3bd53149bf6a98a6835ebcbc9
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\1d\05\04\c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Note: you may need to restart the kernel to use updated packages.Successfully built htmlmin
# ...
#
# ...

# %%
# %%capture
import sys

# !{sys.executable} -m pip install -U pandas-profiling[notebook]
# !jupyter nbextension enable --py widgetsnbextension

# %%
import pandas as pd
from pandas_profiling.utils.cache import cache_file
from pandas_profiling import ProfileReport

# %%
file_name = cache_file(
    "movie_metadata data research.csv",
    "./movie_metadata data research.csv",
)

df = pd.read_csv('./movie_metadata data research.csv', index_col=[0])

# #We will only consider the data from Arizone state for this example
# df = df[df['State']=='Arizona']

# df['Date Local']=pd.to_datetime(df['Date Local'])

# %%
df
# Out:
#            director_name  num_critic_for_reviews  duration  \
# color
# Color      James Cameron                   723.0     178.0
# Color     Gore Verbinski                   302.0     169.0
# Color         Sam Mendes                   602.0     148.0
# Color  Christopher Nolan                   813.0     164.0
# NaN          Doug Walker                     NaN       NaN
# ...                  ...                     ...       ...
# Color        Scott Smith                     1.0      87.0
# Color                NaN                    43.0      43.0
# Color   Benjamin Roberds                    13.0      76.0
# Color        Daniel Hsia                    14.0     100.0
# Color           Jon Gunn                    43.0      90.0
#
#        director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# color
# Color                      0.0                   855.0  Joel David Moore
# Color                    563.0                  1000.0     Orlando Bloom
# ...

# %%
df['Date Local']=pd.to_datetime(df['title_year'])
df
# Out:
#            director_name  num_critic_for_reviews  duration  \
# color
# Color      James Cameron                   723.0     178.0
# Color     Gore Verbinski                   302.0     169.0
# Color         Sam Mendes                   602.0     148.0
# Color  Christopher Nolan                   813.0     164.0
# NaN          Doug Walker                     NaN       NaN
# ...                  ...                     ...       ...
# Color        Scott Smith                     1.0      87.0
# Color                NaN                    43.0      43.0
# Color   Benjamin Roberds                    13.0      76.0
# Color        Daniel Hsia                    14.0     100.0
# Color           Jon Gunn                    43.0      90.0
#
#        director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# color
# Color                      0.0                   855.0  Joel David Moore
# Color                    563.0                  1000.0     Orlando Bloom
# ...

# %%
from pandas_profiling.visualisation.plot import timeseries_heatmap

timeseries_heatmap(dataframe=df, entity_column='duration', sortby='Date Local')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\WORK\PROJECTS\Data Analysis\movie data analysis\mov.ipynb Cell 7 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/WORK/PROJECTS/Data%20Analysis/movie%20data%20analysis/mov.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> from pandas_profiling.visualisation.plot import timeseries_heatmap
# ----> <a href='vscode-notebook-cell:/d%3A/WORK/PROJECTS/Data%20Analysis/movie%20data%20analysis/mov.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> timeseries_heatmap(dataframe=df, entity_column='duration', sortby='Date Local')
#
# File c:\Users\Admin\anaconda3\lib\site-packages\pandas_profiling\visualisation\plot.py:627, in timeseries_heatmap(dataframe, entity_column, sortby, max_entities, selected_entities, figsize, color)
#     611 """Generate a multi entity timeseries heatmap based on a pandas DataFrame.
#     612
#     613 Args:
#    (...)
# ...

# %%
df
# Out:
#       State Code  County Code  Site Num  \
# 0              4           13      3002
# 1              4           13      3002
# 2              4           13      3002
# 3              4           13      3002
# 4              4           13      3002
# ...          ...          ...       ...
# 1271           4           19      1028
# 1272           4           19      1028
# 1273           4           19      1028
# 1274           4           19      1028
# 1275           4           19      1028
#
#                                       Address    State    County     City  \
# 0     1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1     1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 2     1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 3     1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 4     1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# ...

# %%
# Return the profile per station
for group in df.groupby('Site Num'):
    #Running 1 profile per station
    profile = ProfileReport(
        group[1],
        tsmode=True,
        sortby="Date Local",
        #title=f"Air Quality profiling - Site Num: {group[0]}"
    )
    
    profile.to_file(f'Ts_Profile_{group[0]}.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
